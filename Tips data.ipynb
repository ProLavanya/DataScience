# %%
import pandas as pd

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import matplotlib

# %%
df=sns.load_dataset("anscombe")
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# type(df)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['dataset', 'x', 'y'], dtype='object')

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
dataset_1 = df[df['dataset'] =='I']

# %%
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.figure(figsize=(8,5))
plt.plot(dataset_1['x'],dataset_1['y'], '*')

# %%
dataset_2 = df[df['dataset']=='II']
dataset_3 = df[df['dataset']=='III']
dataset_4 = df[df['dataset']=='IV']

# %%
dataset_2
# Out:
#    dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74

# %%
dataset_3
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %%
dataset_4
# Out:
#    dataset     x      y
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
fig=plt.figure(figsize=(8,8))
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)

axes1.plot(dataset_1['x'],dataset_1['y'],'b')
axes2.plot(dataset_2['x'],dataset_2['y'],'r*')
axes3.plot(dataset_3['x'],dataset_3['y'],'g')
axes4.plot(dataset_4['x'],dataset_4['y'],'v')

axes1.set_title("Dataset_1")
axes2.set_title("Dataset_2")
axes3.set_title("Dataset_3")
axes4.set_title("Dataset_4")
fig.suptitle("Anscombe dataset plotting")
fig.tight_layout()

# %%
fig=plt.figure()
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)

axes1.plot(dataset_1['x'],dataset_1['y'],'b')
axes2.plot(dataset_2['x'],dataset_2['y'],'r*')
axes3.plot(dataset_3['x'],dataset_3['y'],'g')
axes4.plot(dataset_4['x'],dataset_4['y'],'v')

axes1.set_title("Dataset_1")
axes2.set_title("Dataset_2")
axes3.set_title("Dataset_3")
axes4.set_title("Dataset_4")
fig.suptitle("Anscombe dataset plotting")
# Out:
# Text(0.5, 0.98, 'Anscombe dataset plotting')

# %%
fig=plt.figure(figsize=(10,10))
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)

axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'r*')
axes3.plot(dataset_3['x'],dataset_3['y'],'*')
axes4.plot(dataset_4['x'],dataset_4['y'],'y.')

axes1.set_title("Dataset_1")
axes2.set_title("Dataset_2")
axes3.set_title("Dataset_3")
axes4.set_title("Dataset_4")
fig.suptitle("Anscombe dataset plotting")
fig.tight_layout()

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig=plt.figure(figsize=(10,8))
axes1=fig.add_subplot(1,1,1)
axes1.hist(df['total_bill'],bins=10,color='green',orientation="vertical")
axes1.set_title(["histrogram of total bills"])
axes1.set_xlabel("frequence")
axes1.set_ylabel("total bill")
# Out:
# Text(0, 0.5, 'total bill')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
df[(df['total_bill']>=10)&(df['total_bill']<=20)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [130 rows x 7 columns]

# %%
import pandas as pd

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.loc[3,"size"]
# Out:
# 2

# %%
tips.iloc[3,-1]
# Out:
# 2

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby("sex").mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
df.groupby("smoker").mean()
# Out:
#         total_bill       tip      size
# smoker
# Yes      20.756344  3.008710  2.408602
# No       19.188278  2.991854  2.668874

# %%
df.groupby("time").mean()
# Out:
#         total_bill       tip      size
# time
# Lunch    17.168676  2.728088  2.411765
# Dinner   20.797159  3.102670  2.630682

# %%
df.groupby("day").mean()
# Out:
#       total_bill       tip      size
# day
# Thur   17.682742  2.771452  2.451613
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105

# %%
df.loc[:,"total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.iloc[:,1:6]
# Out:
#       tip     sex smoker   day    time
# 0    1.01  Female     No   Sun  Dinner
# 1    1.66    Male     No   Sun  Dinner
# 2    3.50    Male     No   Sun  Dinner
# 3    3.31    Male     No   Sun  Dinner
# 4    3.61  Female     No   Sun  Dinner
# ..    ...     ...    ...   ...     ...
# 239  5.92    Male     No   Sat  Dinner
# 240  2.00  Female    Yes   Sat  Dinner
# 241  2.00    Male    Yes   Sat  Dinner
# 242  1.75    Male     No   Sat  Dinner
# 243  3.00  Female     No  Thur  Dinner
#
# [244 rows x 5 columns]

# %%
df[df["size"]==2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [156 rows x 7 columns]

# %%
df.loc[0:5,"tip"]
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# 5    4.71
# Name: tip, dtype: float64

# %%
df[df["sex"]=="Female"]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
len(df[df["smoker"]=="Yes"])
# Out:
# 93

# %%
len(df[df["smoker"]=="No"])
# Out:
# 151

# %%
df[df["sex"]=="Male"]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %% [markdown]
# ### 1.what is the %age of active smoker in the given sample datase

# %%
Active_smoker=df[df["smoker"]=="Yes"]
len(Active_smoker)
# Out:
# 93

# %% [markdown]
#    In the above code we r finding the active smokers data

# %%
(93/244)*100
# Out:
# 38.114754098360656

# %% [markdown]
#     we are finding the average of activesmokers/totalsmokers*100
#     average of activesmokers

# %%
a=len(["smoker"])
p=len(df[df["smoker"]=="Yes"])
l=p/a*100
l
# Out:
# 9300.0

# %% [markdown]
#     average of activesmokers

# %% [markdown]
# ### 2.which gender has mostly occupied space when the table size is 3

# %%
smoke = tips[tips["size"] == 3]
max(smoke["sex"])
# Out:
# 'Male'

# %% [markdown]
#     In the above code male has occupied more space in the tablesize 3

# %%
smoke=df[df["size"]==3]
min(smoke["sex"])
# Out:
# 'Female'

# %% [markdown]
# In the above code female has occupied less space in the tablesize 3

# %% [markdown]
# ### 3.what is the difference amount of data% w.r.t sex

# %%
df[df["sex"]=="Male"].mean()
# Out:
# C:\Users\SRAM31\AppData\Local\Temp/ipykernel_6044/2527027950.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["sex"]=="Male"].mean()
# total_bill    20.744076
# tip            3.089618
# size           2.630573
# dtype: float64

# %% [markdown]
# we are finding the average of male data

# %%
df[df["sex"]=="Female"].mean()
# Out:
# C:\Users\SRAM31\AppData\Local\Temp/ipykernel_6044/1212266009.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["sex"]=="Female"].mean()
# total_bill    18.056897
# tip            2.833448
# size           2.459770
# dtype: float64

# %% [markdown]
# we are finding the average of female data

# %%
s=df[(df["sex"]==18.056897) == (df["sex"] == 20.744076)]
max(s["sex"])
# Out:
# 'Male'

# %% [markdown]
# compare to the male and female percentage, male percentage is greater than  to the female percentage

# %% [markdown]
# ### 4.what is the highest bill paid by sex female

# %%
df[df["sex"] == "Female"]["total_bill"].max()
# Out:
# 44.3

# %% [markdown]
#       female has paid by hightest bill

# %% [markdown]
# highest bill of sex male is 50.81

# %% [markdown]
# ### 5. How much is the difference of highest bill paid by sex female and male

# %%
s = df[(df["sex"] == 44.3) == (df["sex"] == 50.81)]
max(s["sex"])
# Out:
# 'Male'

# %% [markdown]
# the differeence of highest bill paid by in the gender is male

# %%
s = df.loc[:,["total_bill","sex"]]
s
# Out:
#      total_bill     sex
# 0         16.99  Female
# 1         10.34    Male
# 2         21.01    Male
# 3         23.68    Male
# 4         24.59  Female
# ..          ...     ...
# 239       29.03    Male
# 240       27.18  Female
# 241       22.67    Male
# 242       17.82    Male
# 243       18.78  Female
#
# [244 rows x 2 columns]

# %% [markdown]
# ### 6. which gender has offered most valuable tips when tip value is in b\w 10dlr nd 20dlrs

# %%
s=df[(df["size"]>3)&(df["size"]<=6)]
max(s["sex"])
# Out:
# 'Male'

# %%
s.groupby("sex").mean()
# Out:
#         total_bill       tip      size
# sex
# Male     29.092647  4.221176  4.235294
# Female   29.934167  4.210833  4.416667

# %% [markdown]
# ### 7. which time of restaurant visit is mostly preffered by customers

# %%
df["time"].mode()
# Out:
# 0    Dinner
# Name: time, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %% [markdown]
# In the above data finding the mostly preferred the visit restaurant

# %% [markdown]
# ### 8.  Do u think the friday received has highest sale when compare to other days

# %%
df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
Sun_avg=df[df["day"]=="Sun"]["total_bill"].mean()
Sat_avg=df[df["day"]=="Sat"]["total_bill"].mean()
Thur_avg=df[df["day"]=="Thur"]["total_bill"].mean()
Fri_avg=df[df["day"]=="Fri"]["total_bill"].mean()

print("Sunday average value",Sun_avg)
print("saturday average value",Sat_avg)
print("Thurday average value",Thur_avg)
print("Friday average value",Fri_avg)
# Out:
# Sunday average value 21.41
# saturday average value 20.441379310344825
# Thurday average value 17.682741935483868
# Friday average value 17.15157894736842

# %% [markdown]
# ### 9. Between table size 2 & 4 which one has preffered very often

# %%
df_table = df[(df['size'] == 2) | (df['size'] == 4)]
df_table['size'].value_counts()
# Out:
# 2    156
# 4     37
# Name: size, dtype: int64

# %% [markdown]
#     Table number 2 has chosen very often from the conditionally sorted DataFrame of table 2 & 4.

# %%
df[df["size"]==2].shape[0]
# Out:
# 156

# %%
df[df["size"]==4].shape[0]
# Out:
# 37

# %% [markdown]
# ### 10. Which gender has most smoking habit ?please provide % difference

# %%
s=df[df["smoker"]=="Yes"]
s.groupby("sex").mean()
# Out:
#         total_bill       tip      size
# sex
# Male     22.284500  3.051167  2.500000
# Female   17.977879  2.931515  2.242424

# %%
s=df[df["smoker"]=="Yes"]
s.groupby("sex").mean()
max(smoke["sex"])
# Out:
# 'Male'

# %% [markdown]
#        on observation male gender has a mostly smoking habit

# %% [markdown]
# ### 11. What r the infrequent total bill valus in the data set

# %%
df["total_bill"].unique().shape[0]
# Out:
# 229

# %% [markdown]
# ### 12. How do u add a new column to the data set

# %%
df["total_amount"]=df["total_bill"]+df["tip"]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_amount
# 0         16.99  1.01  Female     No   Sun  Dinner     2         18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3         12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3         24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2         26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4         28.20
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2         19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2         21.78
#
# [244 rows x 8 columns]

# %%
df.loc[0:10,["tip"]]
# Out:
#      tip
# 0   1.01
# 1   1.66
# 2   3.50
# 3   3.31
# 4   3.61
# 5   4.71
# 6   2.00
# 7   3.12
# 8   1.96
# 9   3.23
# 10  1.71

# %%
df.iloc[0:5,:-1]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.iloc[0:5,-1]
# Out:
# 0    18.00
# 1    12.00
# 2    24.51
# 3    26.99
# 4    28.20
# Name: total_amount, dtype: float64

# %%
df.iloc[6,-5]
# Out:
# 'No'

# %%
time=df[df["size"]==5]
max(time["sex"])
# Out:
# 'Male'

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_amount
# 0         16.99  1.01  Female     No   Sun  Dinner     2         18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3         12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3         24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2         26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4         28.20
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2         19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2         21.78
#
# [244 rows x 8 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_amount
# 0       16.99  1.01  Female     No  Sun  Dinner     2         18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3         12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3         24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2         26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4         28.20

# %%
df['new_column'] = 7

# %%
df.loc[::]
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_amount  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2         18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3         12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3         24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2         26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4         28.20
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2         19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2         21.78
#
#      new_column
# 0             7
# 1             7
# 2             7
# 3             7
# 4             7
# ...

# %%
df.loc[0::2,["tip","smoker","time"]]
# Out:
#       tip smoker    time
# 0    1.01     No  Dinner
# 2    3.50     No  Dinner
# 4    3.61     No  Dinner
# 6    2.00     No  Dinner
# 8    1.96     No  Dinner
# ..    ...    ...     ...
# 234  3.00    Yes  Dinner
# 236  1.00    Yes  Dinner
# 238  4.67     No  Dinner
# 240  2.00    Yes  Dinner
# 242  1.75     No  Dinner
#
# [122 rows x 3 columns]

# %%
df.loc[0::3,["total_bill","sex","day","size"]]
# Out:
#      total_bill     sex   day  size
# 0         16.99  Female   Sun     2
# 3         23.68    Male   Sun     2
# 6          8.77    Male   Sun     2
# 9         14.78    Male   Sun     2
# 12        15.42    Male   Sun     2
# ..          ...     ...   ...   ...
# 231       15.69    Male   Sat     3
# 234       15.53    Male   Sat     2
# 237       32.83    Male   Sat     2
# 240       27.18  Female   Sat     2
# 243       18.78  Female  Thur     2
#
# [82 rows x 4 columns]

# %%
df.loc[0::2,['total_bill','sex','day']]
# Out:
#      total_bill     sex  day
# 0         16.99  Female  Sun
# 2         21.01    Male  Sun
# 4         24.59  Female  Sun
# 6          8.77    Male  Sun
# 8         15.04    Male  Sun
# ..          ...     ...  ...
# 234       15.53    Male  Sat
# 236       12.60    Male  Sat
# 238       35.83  Female  Sat
# 240       27.18  Female  Sat
# 242       17.82    Male  Sat
#
# [122 rows x 3 columns]

# %% [markdown]
# ### 13. Which day has lowest sale  value?

# %%
df.groupby("day")["total_bill"].min()
# Out:
# day
# Thur    7.51
# Fri     5.75
# Sat     3.07
# Sun     7.25
# Name: total_bill, dtype: float64
